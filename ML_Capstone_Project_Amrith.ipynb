# %% [markdown]
# **Name:Amrith Vasundharan**
#
#
# DS28A Batch

# %% [markdown]
# #**Section 1: Questions to Answer**

# %% [markdown]
# **1.Why is your proposal important in today’s world? How predicting a disease accurately can improve medical treatment?**
#
# Answer:
#
#
#
# **Predictive Modeling in Pandemics: Harnessing Machine Learning for Advanced COVID-19 Forecasting and Preparedness**
#
#
# **Importance of Predictive Modeling in the Context of COVID-19:**
#
# **Early Detection and Preparedness**: Accurate prediction models can provide early warning signals for potential disease outbreaks, enabling healthcare systems and authorities to implement proactive measures, allocate resources efficiently, and mitigate the impact of the disease on communities.
#
# **Resource Allocation Optimization:** Predictive modeling allows for the optimization of resource allocation, ensuring that medical facilities have the necessary supplies, personnel, and infrastructure in place to effectively manage an influx of COVID-19 cases. This, in turn, enhances the overall resilience of healthcare systems.
#
# **Strategic Intervention Planning**: Forecasting the trajectory of the disease enables the development of targeted and data-driven intervention strategies. This can include the implementation of localized lockdowns, vaccination campaigns, and other preventive measures to curb the spread of the virus and minimize its impact on vulnerable populations.
#
# **Treatment Protocol Enhancement**: Accurate predictions contribute to the refinement of treatment protocols by providing insights into the expected patient caseload, severity of cases, and potential complications. This information empowers healthcare professionals to tailor treatment plans, allocate critical resources judiciously, and optimize patient care.
#
# **Public Health Communication**: Predictive models aid in effective communication of public health measures by offering clear projections and evidence-based recommendations. This fosters public understanding and compliance, ultimately contributing to the success of containment efforts.
#
#
# **Improving Medical Treatment Outcomes:**
#
# **Personalized Medicine**: Accurate disease forecasting allows for the implementation of personalized medicine approaches. Healthcare providers can tailor treatment plans based on predicted disease severity, patient demographics, and other relevant factors, optimizing individual outcomes.
#
# **Resource-Efficient Healthcare Delivery**: By anticipating the demand for medical resources, healthcare facilities can streamline their operations, ensuring that critical treatments and interventions are available to those who need them most. This enhances overall healthcare delivery efficiency.
#
# **Research and Development Focus**: Predictive modeling can guide research and development efforts towards areas with the highest predicted impact, facilitating the rapid development of targeted therapies, vaccines, and medical interventions.
#
# **Data-Driven Decision-Making**: The integration of accurate predictive models into clinical decision-making processes empowers healthcare professionals to make informed, data-driven choices in real-time, leading to more effective and efficient patient care.
#
# In conclusion, the proposed project aims to harness the power of advanced predictive modeling to revolutionize our approach to managing COVID-19. By accurately forecasting the trajectory of the disease, we can not only enhance the effectiveness of public health interventions but also significantly improve medical treatment outcomes. This endeavor represents a critical step towards building a more resilient and adaptive healthcare system capable of effectively responding to current and future pandemics.

# %% [markdown]
# **2.How is it going to impact the medical field when it comes to effective screening and reducing health care burden.**
#
#
#
# By employing advanced machine learning models to analyze COVID-19 data, our project enhances medical screening efficacy. Identifying patterns such as the relation between symptoms like cough, fever, sore throat, shortness of breath, headache and age with positive COVID-19 outcomes allows for targeted and proactive medical interventions. This insight enables healthcare providers to prioritize and tailor treatments based on symptomatology, reducing diagnosis time and healthcare burdens. Timely identification also facilitates preparedness with appropriate medicines and vaccinations, fostering a more proactive and effective approach to managing COVID-19 cases and alleviating strain on healthcare systems.

# %% [markdown]
# **3.If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any other disease.**
#
# The machine learning model developed can serve as a versatile framework for predicting and understanding the spread of various infectious diseases more eeficiently by incorporating a broader set of symptoms like body aches or muscle pains,fatigue,diarrhea,vomitting,loss of taste or smell and continuously updating the model with emerging data, we can enhance its adaptability to different diseases. Additionally, integrating real-time data streams, such as mobility patterns and social interactions, can further improve the efficiency of predicting COVID-19 tests. This comprehensive approach ensures the scalability and applicability of the model for addressing unforeseen health challenges beyond the current pandemic.

# %% [markdown]
# #**Section 2: Initial Hypothesis**
#
# 1. All the symptoms like Cough_symptoms,Fever,Headache,Sore_throat,Shortness_of_breath does not have a relationship with Corona test being positive.
#
# 2. kNN CLassifier is a good ML algorithm than Decision Tree Classifier.
#
# 3. SVM CLassifier is a good ML algorithm than kNN Classifier.

# %% [markdown]
# #**Section 3: Data analysis approach**
#
# - 1.Understand the Business problem- in this dataset we need to identify which features affect Covid-19 and how can we predict Covid-19 by using those features.
# - 2.Feature Engineering-Data understanding(Data exploration, Cleaning, Missing valyes, outliers(if any)) and EDA
# - 3.Model training
# - 4.Model evaluation
# - 5.Hyper parameter tuning
# - 6.Conclusion

# %% [markdown]
# **Feature Engineering**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("corona_tested_006.csv")
# Out:
# <ipython-input-45-6abef59c73ee>:1: DtypeWarning: Columns (2,3,4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("corona_tested_006.csv")

# %% [markdown]
# **Data Exploration, Preprocessing and Exploratory Data Analysis(EDA)**

# %%
df
# Out:
#         Ind_ID   Test_date Cough_symptoms  Fever Sore_throat  \
# 0            1  11-03-2020           TRUE  FALSE        TRUE
# 1            2  11-03-2020          FALSE   TRUE       FALSE
# 2            3  11-03-2020          FALSE   TRUE       FALSE
# 3            4  11-03-2020           TRUE  FALSE       FALSE
# 4            5  11-03-2020           TRUE  FALSE       FALSE
# ...        ...         ...            ...    ...         ...
# 278843  278844  30-04-2020          False  False       False
# 278844  278845  30-04-2020          False  False       False
# 278845  278846  30-04-2020          False  False       False
# 278846  278847  30-04-2020          False  False       False
# 278847  278848  30-04-2020          False  False       False
#
#        Shortness_of_breath Headache    Corona Age_60_above     Sex  \
# 0                    FALSE    FALSE  negative         None    None
# 1                    FALSE    FALSE  positive         None    None
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278848 entries, 0 to 278847
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Ind_ID               278848 non-null  int64
#  1   Test_date            278848 non-null  object
#  2   Cough_symptoms       278848 non-null  object
#  3   Fever                278848 non-null  object
#  4   Sore_throat          278848 non-null  object
#  5   Shortness_of_breath  278848 non-null  object
#  6   Headache             278848 non-null  object
#  7   Corona               278848 non-null  object
#  8   Age_60_above         278848 non-null  object
#  9   Sex                  278848 non-null  object
#  10  Known_contact        278848 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 23.4+ MB

# %%
df.isnull().sum()
# Out:
# Ind_ID                 0
# Test_date              0
# Cough_symptoms         0
# Fever                  0
# Sore_throat            0
# Shortness_of_breath    0
# Headache               0
# Corona                 0
# Age_60_above           0
# Sex                    0
# Known_contact          0
# dtype: int64

# %% [markdown]
# **Getting the unique values in each categorical column**

# %%
df['Cough_symptoms'].unique()
# Out:
# array(['TRUE', 'FALSE', 'None', False, True], dtype=object)

# %%
df['Cough_symptoms'].value_counts()
# Out:
# False    127531
# FALSE    108837
# TRUE      21983
# True      20245
# None        252
# Name: Cough_symptoms, dtype: int64

# %%
df['Fever'].unique()
# Out:
# array(['FALSE', 'TRUE', 'None', False, True], dtype=object)

# %%
df['Sore_throat'].unique()
# Out:
# array(['TRUE', 'FALSE', 'None', False, True], dtype=object)

# %%
df['Shortness_of_breath'].unique()
# Out:
# array(['FALSE', 'TRUE', 'None', False, True], dtype=object)

# %%
df['Headache'].unique()
# Out:
# array(['FALSE', 'TRUE', 'None', False, True], dtype=object)

# %%
df['Corona'].unique()
# Out:
# array(['negative', 'positive', 'other'], dtype=object)

# %%
df['Age_60_above'].unique()
# Out:
# array(['None', 'No', 'Yes'], dtype=object)

# %%
df['Age_60_above'].value_counts()
# Out:
# None    127320
# No      125703
# Yes      25825
# Name: Age_60_above, dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['None', 'male', 'female'], dtype=object)

# %%
df['Known_contact'].unique()
# Out:
# array(['Abroad', 'Contact with confirmed', 'Other'], dtype=object)

# %% [markdown]
# Reading the data using Pandas and converting into Pandas DataFrame with **index_col=0**(used to avoid extra column for indexing) and **na_values="None"** is used to replace None values to NaN and also convert string to resembling Trueor False values.

# %%
df=pd.read_csv("corona_tested_006.csv",index_col=0, na_values='None')
# Out:
# <ipython-input-63-a55691ad6e33>:1: DtypeWarning: Columns (2,3,4,5,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("corona_tested_006.csv",index_col=0, na_values='None')

# %%
df.shape
# Out:
# (278848, 10)

# %%
df.isnull().sum()
# Out:
# Test_date                   0
# Cough_symptoms            252
# Fever                     252
# Sore_throat                 1
# Shortness_of_breath         1
# Headache                    1
# Corona                      0
# Age_60_above           127320
# Sex                     19563
# Known_contact               0
# dtype: int64

# %% [markdown]
# **Dropping the insignificant column- as it wont affect the output variable(Corona)**

# %%
df=df.drop(['Test_date','Known_contact'],axis=1)

# %% [markdown]
# **Filling the Missing Values**

# %%
df['Cough_symptoms']=df['Cough_symptoms'].fillna(df['Cough_symptoms'].mode()[0])

# %%
df['Cough_symptoms'].unique()
# Out:
# array([ True, False])

# %%
df['Fever']=df["Fever"].fillna(df["Fever"].mode()[0])

# %%
df['Sore_throat']=df["Sore_throat"].fillna(df["Sore_throat"].mode()[0])

# %%
df['Shortness_of_breath']=df["Shortness_of_breath"].fillna(df["Shortness_of_breath"].mode()[0])

# %%
df["Headache"]=df["Headache"].fillna(df["Headache"].mode()[0])

# %%
df["Age_60_above"]=df["Age_60_above"].fillna(df["Age_60_above"].mode()[0])

# %%
df["Sex"]=df["Sex"].fillna(df["Sex"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Cough_symptoms         0
# Fever                  0
# Sore_throat            0
# Shortness_of_breath    0
# Headache               0
# Corona                 0
# Age_60_above           0
# Sex                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278848 entries, 1 to 278848
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cough_symptoms       278848 non-null  bool
#  1   Fever                278848 non-null  bool
#  2   Sore_throat          278848 non-null  bool
#  3   Shortness_of_breath  278848 non-null  bool
#  4   Headache             278848 non-null  bool
#  5   Corona               278848 non-null  object
#  6   Age_60_above         278848 non-null  object
#  7   Sex                  278848 non-null  object
# dtypes: bool(5), object(3)
# memory usage: 9.8+ MB

# %%
df.describe()
# Out:
#        Cough_symptoms   Fever Sore_throat Shortness_of_breath Headache  \
# count          278848  278848      278848              278848   278848
# unique              2       2           2                   2        2
# top             False   False       False               False    False
# freq           236620  257096      276922              277271   276434
#
#           Corona Age_60_above     Sex
# count     278848       278848  278848
# unique         3            2       2
# top     negative           No  female
# freq      260227       253023  149721

# %% [markdown]
# **Univariate Analysis**

# %%
df['Cough_symptoms'].value_counts()
# Out:
# False    236620
# True      42228
# Name: Cough_symptoms, dtype: int64

# %%
sns.countplot(data=df, x="Cough_symptoms")
# Out:
# <Axes: xlabel='Cough_symptoms', ylabel='count'>

# %%
df['Fever'].value_counts()
# Out:
# False    257096
# True      21752
# Name: Fever, dtype: int64

# %%
sns.countplot(data=df, x="Fever")
# Out:
# <Axes: xlabel='Fever', ylabel='count'>

# %%
df['Sore_throat'].value_counts()
# Out:
# False    276922
# True       1926
# Name: Sore_throat, dtype: int64

# %%
sns.countplot(data=df, x="Sore_throat")
# Out:
# <Axes: xlabel='Sore_throat', ylabel='count'>

# %%
df['Shortness_of_breath'].value_counts()
# Out:
# False    277271
# True       1577
# Name: Shortness_of_breath, dtype: int64

# %%
sns.countplot(data=df, x="Shortness_of_breath")
# Out:
# <Axes: xlabel='Shortness_of_breath', ylabel='count'>

# %%
df["Headache"].value_counts()
# Out:
# False    276434
# True       2414
# Name: Headache, dtype: int64

# %%
sns.countplot(data=df,x="Headache")
# Out:
# <Axes: xlabel='Headache', ylabel='count'>

# %%
df["Corona"].value_counts()
# Out:
# negative    260227
# positive     14729
# other         3892
# Name: Corona, dtype: int64

# %%
sns.countplot(data=df,x="Corona")
# Out:
# <Axes: xlabel='Corona', ylabel='count'>

# %%
df['Age_60_above'].value_counts()
# Out:
# No     253023
# Yes     25825
# Name: Age_60_above, dtype: int64

# %%
sns.countplot(data=df,x="Age_60_above")
# Out:
# <Axes: xlabel='Age_60_above', ylabel='count'>

# %%
df["Sex"].value_counts()
# Out:
# female    149721
# male      129127
# Name: Sex, dtype: int64

# %%
sns.countplot(data=df,x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Bivariate Analysis- we can use heatmap, crosstab, chi-square test
#
# Since all the variables are categorical- we use **Chi square test** and **heatmap**.
#
# The Chi squ test is applied when you have two categorical variables from a single population. It is used to determine whether there is a significant association between the two variables.

# %%
import scipy.stats as stats

# %% [markdown]
# Two way Tables- use pd.crosstab()- it is used to get the frequency distribution of Corona with respect to other categorical variables.

# %% [markdown]
# Bivariate Analysis of **Cough_symptoms** and **Corona**.
#
# Null Hypothesis: There is no relation between categorical variables.

# %%
df_observed_cough=pd.crosstab(index=df['Corona'],columns=df["Cough_symptoms"])   #Actual Observations

# %%
df_observed_cough
# Out:
# Cough_symptoms   False  True
# Corona
# negative        225240  34987
# other             3235    657
# positive          8145   6584

# %%
#Observed Values
Corona_cough_observed_values=df_observed_cough.values
print("Corona_Cough_observed:-\n",Corona_cough_observed_values)
# Out:
# Corona_Cough_observed:-
#  [[225240  34987]
#  [  3235    657]
#  [  8145   6584]]

# %%
val_corona_cough=stats.chi2_contingency(df_observed_cough)

# %%
val_corona_cough
# Out:
# Chi2ContingencyResult(statistic=10607.073099213541, pvalue=0.0, dof=2, expected_freq=array([[220818.91474925,  39408.08525075],
#        [  3302.60586413,    589.39413587],
#        [ 12498.47938662,   2230.52061338]]))

# %%
Corona_cough_expected_values=val_corona_cough[3]

# %%
no_of_rows=len(df_observed_cough.iloc[0:3,0])
no_of_columns=len(df_observed_cough.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degrees of Freedom:-",ddof)
alpha=0.05
# Out:
# Degrees of Freedom:- 2

# %%
chi_square=sum([(o-e)**2./e for o,e in zip(Corona_cough_observed_values,Corona_cough_expected_values)])
print(chi_square)
# Out:
# [1606.30695875 9000.76614046]

# %%
chi_square_statistic=chi_square[0]+chi_square[1]
print("Chi-square statistic:",chi_square_statistic)
# Out:
# Chi-square statistic: 10607.073099213541

# %%
#p-value
from scipy.stats import chi2
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
# Out:
# p-value: 0.0
# Significance level:  0.05
# Degree of Freedom:  2

# %%
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Reject H0,There is a relationship between 2 categorical variables

# %%
sns.heatmap(pd.crosstab(df['Corona'],df['Cough_symptoms']),annot=True)
# Out:
# <Axes: xlabel='Cough_symptoms', ylabel='Corona'>

# %% [markdown]
# Bivariate Analysis of **Fever** and **Corona**.
#
# Null Hypothesis: There is no relation between categorical variables.

# %%
df_fever=pd.crosstab(df['Corona'],df["Fever"])

# %%
df_fever
# Out:
# Fever      False  True
# Corona
# negative  244411  15816
# other       3515    377
# positive    9170   5559

# %%
#Observed Values
Observed_fever_values=df_fever.values
print("Observed_fever_values:",Observed_fever_values)
# Out:
# Observed_fever_values: [[244411  15816]
#  [  3515    377]
#  [  9170   5559]]

# %%
val_corona_fever=stats.chi2_contingency(df_fever)
val_corona_fever
# Out:
# Chi2ContingencyResult(statistic=19452.401689420978, pvalue=0.0, dof=2, expected_freq=array([[239927.56194056,  20299.43805944],
#        [  3588.39809502,    303.60190498],
#        [ 13580.03996443,   1148.96003557]]))

# %%
Expected_fever_values=val_corona_fever[3]

# %%
no_of_rows=len(df_fever.iloc[0:3,0])
no_of_columns=len(df_fever.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degrees of Freedom:-",ddof)
alpha=0.05
# Out:
# Degrees of Freedom:- 2

# %%
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_fever_values,Expected_fever_values)])
print(chi_square)
# Out:
# [ 1517.4168061  17934.98488332]

# %%
chi_square_statistic=chi_square[0]+chi_square[1]
print("Chi-square statistic:",chi_square_statistic)
# Out:
# Chi-square statistic: 19452.401689420978

# %%
#p-value
from scipy.stats import chi2
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
# Out:
# p-value: 0.0
# Significance level:  0.05
# Degree of Freedom:  2

# %%
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Reject H0,There is a relationship between 2 categorical variables

# %%
sns.heatmap(pd.crosstab(df['Corona'],df['Fever']),annot=True)
# Out:
# <Axes: xlabel='Fever', ylabel='Corona'>

# %% [markdown]
# Bivariate Analysis of **Sore_throat** and **Corona**.
#
# Null Hypothesis: There is no relation between categorical variables.

# %%
df_sorethroat=pd.crosstab(df['Sore_throat'],df['Corona'])
df_sorethroat
# Out:
# Corona       negative  other  positive
# Sore_throat
# False          259861   3858     13203
# True              366     34      1526

# %%
#Observed Values
Observed_sorethroat_values=df_sorethroat.values
print("Observed_fever_values:",Observed_sorethroat_values)
# Out:
# Observed_fever_values: [[259861   3858  13203]
#  [   366     34   1526]]

# %%
val_corona_sorethroat=stats.chi2_contingency(df_sorethroat)
val_corona_sorethroat
# Out:
# Chi2ContingencyResult(statistic=21228.2207042624, pvalue=0.0, dof=2, expected_freq=array([[2.58429615e+05, 3.86511800e+03, 1.46272670e+04],
#        [1.79738496e+03, 2.68820002e+01, 1.01733037e+02]]))

# %%
Expected_sorethroat_values=val_corona_sorethroat[3]

# %%
no_of_rows=len(df_sorethroat.iloc[0:2,0])
no_of_columns=len(df_sorethroat.iloc[0,0:3])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degrees of Freedom:-",ddof)
alpha=0.05
# Out:
# Degrees of Freedom:- 2

# %%
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_sorethroat_values,Expected_sorethroat_values)])
print(chi_square)
# Out:
# [1.14784136e+03 1.89786114e+00 2.00784815e+04]

# %%
chi_square_statistic=chi_square[0]+chi_square[1]+chi_square[2]
print("Chi-square statistic:",chi_square_statistic)
# Out:
# Chi-square statistic: 21228.2207042624

# %%
#p-value
from scipy.stats import chi2
p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)
# Out:
# p-value: 0.0
# Significance level:  0.05
# Degree of Freedom:  2

# %%
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Reject H0,There is a relationship between 2 categorical variables

# %%
sns.heatmap(pd.crosstab(df['Corona'],df['Sore_throat']),annot=True)
# Out:
# <Axes: xlabel='Sore_throat', ylabel='Corona'>

# %% [markdown]
# Bivariate Analysis of **Sex** and **Corona**.
#
# Null Hypothesis: There is no relation between categorical variables.

# %%
df_sex=pd.crosstab(df['Corona'],df['Sex'])

#Observed Values
Observed_sex_values=df_sex.values
print("Observed_fever_values:",Observed_sex_values)

#Chi2_contingency calculation
val_corona_sex=stats.chi2_contingency(df_sex)
print(val_corona_sex)


#Expected values
Expected_sex_values=val_corona_sex[3]

#DDOF
no_of_rows=len(df_sex.iloc[0:3,0])
no_of_columns=len(df_sex.iloc[0,0:2])
ddof=(no_of_rows-1)*(no_of_columns-1)
print("Degrees of Freedom:-",ddof)
alpha=0.05


#chi_sqaure_statistic calculation
chi_square=sum([(o-e)**2./e for o,e in zip(Observed_sex_values,Expected_sex_values)])
chi_square_statistic1=chi_square[0]+chi_square[1]
print("Chi-square statistic:",chi_square_statistic)


#p-value
from scipy.stats import chi2
p_value=1-chi2.cdf(x=chi_square_statistic1,df=ddof)
print('p-value:',p_value)
print('Significance level: ',alpha)
print('Degree of Freedom: ',ddof)

#Conclusion
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables")
else:
    print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
# Observed_fever_values: [[140376 119851]
#  [  2135   1757]
#  [  7210   7519]]
# Chi2ContingencyResult(statistic=141.89987843019287, pvalue=1.5375629573328895e-31, dof=2, expected_freq=array([[139722.88367498, 120504.11632502],
#        [  2089.71960351,   1802.28039649],
#        [  7908.39672151,   6820.60327849]]))
# Degrees of Freedom:- 2
# Chi-square statistic: 21228.2207042624
# p-value: 0.0
# Significance level:  0.05
# Degree of Freedom:  2
# Reject H0,There is a relationship between 2 categorical variables

# %%
sns.heatmap(pd.crosstab(df['Corona'],df['Sex']),annot=True)
# Out:
# <Axes: xlabel='Sex', ylabel='Corona'>

# %% [markdown]
# Bivariate Analysis of **Shortness_of_breath** and **Corona**.
#
# Null Hypothesis: There is no relation between categorical variables.

# %%
df_breath=pd.crosstab(df['Corona'],df['Shortness_of_breath'])


#Chi2_contingency calculation
val_corona_shortness_of_breath=stats.chi2_contingency(df_breath)
print(val_corona_shortness_of_breath)


#p-value
p_value=val_corona_shortness_of_breath[1]

alpha=0.05

#Conclusion
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables with 95% confidence.")
else:
    print("Retain H0,There is no relationship between 2 categorical variables with 95% confidence.")
# Out:
# Chi2ContingencyResult(statistic=14909.195898772838, pvalue=0.0, dof=2, expected_freq=array([[2.58755309e+05, 1.47169059e+03],
#        [3.86998914e+03, 2.20108590e+01],
#        [1.46457015e+04, 8.32985462e+01]]))
# Reject H0,There is a relationship between 2 categorical variables with 95% confidence.

# %%
df_age=pd.crosstab(df['Corona'],df['Age_60_above'])


#Chi2_contingency calculation
val_corona_age=stats.chi2_contingency(df_age)
print(val_corona_age)


#p-value
p_value=val_corona_age[1]

alpha=0.05

#Conclusion
if p_value<=alpha:
    print("Reject H0,There is a relationship between 2 categorical variables with 95% confidence.")
else:
    print("Retain H0,There is no relationship between 2 categorical variables with 95% confidence.")
# Out:
# Chi2ContingencyResult(statistic=610.0741400568827, pvalue=3.342594626754877e-133, dof=2, expected_freq=array([[236126.55002367,  24100.44997633],
#        [  3531.54950367,    360.45049633],
#        [ 13364.90047266,   1364.09952734]]))
# Reject H0,There is a relationship between 2 categorical variables with 95% confidence.

# %%
df.head()
# Out:
#         Cough_symptoms  Fever  Sore_throat  Shortness_of_breath  Headache  \
# Ind_ID
# 1                 True  False         True                False     False
# 2                False   True        False                False     False
# 3                False   True        False                False     False
# 4                 True  False        False                False     False
# 5                 True  False        False                False     False
#
#           Corona Age_60_above     Sex
# Ind_ID
# 1       negative           No  female
# 2       positive           No  female
# 3       positive           No  female
# 4       negative           No  female
# 5       negative           No  female

# %% [markdown]
# #**Machine Learning Modelling**

# %% [markdown]
# **Since the Target Variable "Corona" is a categorical variable- applying various Classification Techniques.**

# %% [markdown]
# **1. Decision Tree Classifier**

# %%
import time

start_time=time.time()
#Seperate the features
X=df[['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"]]
y=df["Corona"]

#Convert the categorical variable into Numerical Data using One shot encoding
X=pd.get_dummies(X,columns=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"],drop_first=True)

#Split the data into Training and Testing Sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=True)


from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()
model.fit(X_train,y_train)


#Make predictions on testing data
y_pred_test=model.predict(X_test)
y_pred_train=model.predict(X_train)

#Evaluation
from sklearn.metrics import accuracy_score
print("Train Accuracy:", accuracy_score(y_train,y_pred_train))
print("Test Accuracy:",accuracy_score(y_test,y_pred_test))
end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Train Accuracy: 0.9444857852410368
# Test Accuracy: 0.9446476600322754
# Elapsed time: 1.5776946544647217 seconds

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,X_train,y_train,cv=5).mean()  #Cross Validation score

print("Cross Validation Score:",cross_val_score(model,X_train,y_train,cv=5).mean() )
# Out:
# Cross Validation Score: 0.9444499254283821

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV


estimator=DecisionTreeClassifier()
param_grid={"max_depth":list(range(1,10))}   #param_grid={"max_depth":list(range(1,11))}
grid= GridSearchCV(estimator,param_grid,cv=5)
grid.fit(X_train,y_train)

grid.best_params_
# Out:
# {'max_depth': 7}

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(24,12),dpi=300)

plot_tree(model,filled=True,feature_names=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"])

plt.show()

# %% [markdown]
# **2.Logistic Regression**

# %%
import time

start_time=time.time()

#Seperate the features
X=df[['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"]]
y=df["Corona"]

#Convert the categorical variable into Numerical Data using One shot encoding
X=pd.get_dummies(X,columns=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"],drop_first=True)

#Split the data into Training and Testing Sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=True)

#Modelling
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train, y_train)

#Predicting the values
y_pred=model.predict(X_test)

#Evaluate the model performance
from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred))

print("===========================================================================================================================================")

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Accuracy Score: 0.9438228438228439
# ...
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#     negative       0.94      1.00      0.97     52038
#        other       0.00      0.00      0.00       752
#     positive       0.88      0.23      0.37      2980
#
#     accuracy                           0.94     55770
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,X_train,y_train,cv=5).mean()  #Cross Validation score

print("Cross Validation Score:",cross_val_score(model,X_train,y_train,cv=5).mean() )
# Out:
# Cross Validation Score: 0.9436295845810584

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
estimator=LogisticRegression()
param_grid=dict(solver=solvers,penalty=penalty,C=c_values)   #param_grid={"max_depth":list(range(1,11))}
grid= GridSearchCV(estimator,param_grid=param_grid,cv=5)
grid.fit(X_train,y_train)

grid.best_params_
# Out:
# {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}

# %% [markdown]
# **3.kNN Classifier**

# %%
import time

start_time=time.time()

#Seperate the features
X=df[['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"]]
y=df["Corona"]

#Convert the categorical variable into Numerical Data using One shot encoding
X=pd.get_dummies(X,columns=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"],drop_first=True)

#Split the data into Training and Testing Sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=True)


#Modelling
#Initialize a kNN classifier
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()  #by default n_neighbors=5=5/KNeighborsClassifier(n_neighbors=i)
model.fit(X_train,y_train)

#Prediction and Evaluation
from sklearn.metrics import accuracy_score

ypred_test=model.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test,ypred_test))

end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Test Accuracy: 0.9442531827147211
# Elapsed time: 119.40737986564636 seconds

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,X_train,y_train,cv=5).mean()  #Cross Validation score

print("Cross Validation Score:",cross_val_score(model,X_train,y_train,cv=5).mean() )

# %% [markdown]
# Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV


estimator=KNeighborsClassifier()
param_grid={'n_neighbors':list(range(2,10))}   #param_grid={"max_depth":list(range(1,11))}
grid= GridSearchCV(estimator,param_grid,cv=5)
grid.fit(X_train,y_train)

grid.best_params_

# %% [markdown]
# **4. XGBoost Classifier**

# %%
import time

start_time=time.time()

#Seperate the features
X=df[['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"]]
y=df["Corona"]

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(df["Corona"])


#Convert the categorical variable into Numerical Data using One shot encoding
X=pd.get_dummies(X,columns=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"],drop_first=True)

#Split the data into Training and Testing Sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=True)


#Modelling of XGBoost
import xgboost as xgb
model=xgb.XGBClassifier()
model.fit(X_train,y_train)


#Make prediction on the testing data
y_pred=model.predict(X_test)


#Evaluate the model performance
from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred))

end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Accuracy Score: 0.944665590819437
# Elapsed time: 5.227917671203613 seconds

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(model,X_train,y_train,cv=5).mean()  #Cross Validation score

print("Cross Validation Score:",cross_val_score(model,X_train,y_train,cv=5).mean() )
# Out:
# Cross Validation Score: 0.9444588908219629

# %% [markdown]
# **5. SVM Classifier**

# %%
import time

start_time=time.time()

#Seperate the features
X=df[['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"]]
y=df["Corona"]

#Convert the categorical variable into Numerical Data using One shot encoding
X=pd.get_dummies(X,columns=['Cough_symptoms',"Fever","Sore_throat","Shortness_of_breath","Headache","Sex","Age_60_above"],drop_first=True)

#Split the data into Training and Testing Sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=True)

#Modelling
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)


#Make predictions on the testing data
y_pred=model.predict(X_test)
ypred_train= model.predict(X_train)

#Calculate Evaluation Metrics

from sklearn.metrics import accuracy_score
print("Test Accuracy:",accuracy_score(y_test,y_pred))
print("Train Accuracy:",accuracy_score(y_train,ypred_train))

end_time = time.time()

elapsed_time = end_time - start_time

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Test Accuracy: 0.944665590819437
# Train Accuracy: 0.9444857852410368
# Elapsed time: 811.2731003761292 seconds

# %% [markdown]
# #**Conclusions on Different Machine Learning Techniques implemented**
#
# - 1. **Decision Tree Classifier**
#
#       Test Accuracy Score: 94.46%
#
#       Execution Time:1.5776946544647217 seconds
#
# - 2. **Logistic Regression**
#
#       Test Accuracy Score: 94.38%
#
#       Execution Time:6.138659954071045 seconds
#
# - 3. **kNN Classifier**
#
#       Test Accuracy Score: 94.42%
#
#       Execution Time:119.40737986564636 seconds
#
# - 4. **XGBoost Classifier**
#
#       Test Accuracy Score: 94.46%
#
#       Execution Time:5.227917671203613 seconds
#
# - 5. **SVM Classifier**
#
#       Test Accuracy Score: 94.46%
#
#       Execution Time:811.2731003761292 seconds
#
#
# Observing the Accuracy Scores and Execution Time after Hyperparameter tuning of every classifier Machine Learning Algorithms: **Decision Tree Classifier** is most suited for this Data set considering the features after cleaning for predicting Covid-19(Corona)

# %% [markdown]
# #**Hypothesis Result**
#
# 1. All the symptoms like Cough_symptoms,Fever,Headache,Sore_throat,Shortness_of_breath ***does have a relationship*** with Corona test being positive.
#
# 2. kNN CLassifier ***is not a good ML algorithm*** than Decision Tree Classifier for this data set.
#
# 3. SVM CLassifier ***is not a good ML algorithm*** than kNN Classifier for this data set.

# %% [markdown]
# #**Questions to be solved using MySQL**
#
#
# *Cleaned Data need to be used*
#
# 1. Find the number of corona patients who faced shortness of breath.
#
# 2. Find the number of negative corona patients who have fever and sore_throat.
#
# 3. Group the data by month and rank the number of positive cases.
#
# 4. Find the female negative corona patients who faced cough and headache.
#
# 5. How many elderly corona patients have faced breathing problems?
#
# 6. Which three symptoms were more common among COVID positive patients?
#
# 7. Which symptom was less common among COVID negative people?
#
# 8. What are the most common symptoms among COVID positive males whose known contact was abroad?

# %%
import duckdb
import pandas as pd

# %% [markdown]
# Again the data set was uploaded and cleaned without deleting the "Test_date" using pandas because in the questions "Test_date" columns was required.

# %%
df=pd.read_csv("corona_tested_006.csv",index_col=0, na_values='None')
# Out:
# <ipython-input-137-a55691ad6e33>:1: DtypeWarning: Columns (2,3,4,5,6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("corona_tested_006.csv",index_col=0, na_values='None')

# %%
df['Cough_symptoms']=df['Cough_symptoms'].fillna(df['Cough_symptoms'].mode()[0])
df['Fever']=df["Fever"].fillna(df["Fever"].mode()[0])
df['Sore_throat']=df["Sore_throat"].fillna(df["Sore_throat"].mode()[0])
df['Shortness_of_breath']=df["Shortness_of_breath"].fillna(df["Shortness_of_breath"].mode()[0])
df["Headache"]=df["Headache"].fillna(df["Headache"].mode()[0])
df["Age_60_above"]=df["Age_60_above"].fillna(df["Age_60_above"].mode()[0])
df["Sex"]=df["Sex"].fillna(df["Sex"].mode()[0])

# %%
df['Test_date'] = pd.to_datetime(df['Test_date'],format='%d-%m-%Y')

# %%
conn=duckdb.connect()
conn.register('df',df)

# %%
df.head(5)
# Out:
#         Test_date  Cough_symptoms  Fever  Sore_throat  Shortness_of_breath  \
# Ind_ID
# 1      2020-03-11            True  False         True                False
# 2      2020-03-11           False   True        False                False
# 3      2020-03-11           False   True        False                False
# 4      2020-03-11            True  False        False                False
# 5      2020-03-11            True  False        False                False
#
#         Headache    Corona Age_60_above     Sex           Known_contact
# Ind_ID
# 1          False  negative           No  female                  Abroad
# 2          False  positive           No  female                  Abroad
# 3          False  positive           No  female                  Abroad
# 4          False  negative           No  female                  Abroad
# 5          False  negative           No  female  Contact with confirmed

# %% [markdown]
# **1.Find the number of corona patients who faced shortness of breath.**

# %%
conn.execute("select count(*) as No_of_covid_patients_with_breathshortness from df where Corona='positive' and Shortness_of_breath='True'").fetchdf()
# Out:
#    No_of_covid_patients_with_breathshortness
# 0                                       1164

# %% [markdown]
# **2. Find the number of negative corona patients who have fever and sore_throat.**

# %%
conn.execute("select count(*) as No_of_covid_patients_fever_sorethroat from df where Corona='negative' and Fever='True' and Sore_throat='True'").fetchdf()
# Out:
#    No_of_covid_patients_fever_sorethroat
# 0                                    121

# %% [markdown]
# **3.Group the data by month and rank the number of positive cases.**

# %%
conn.execute("SELECT EXTRACT(MONTH FROM Test_date) AS month, COUNT(*) AS positive_cases_count, RANK() OVER (ORDER BY COUNT(*) DESC) AS case_rank FROM df WHERE Corona = 'positive' GROUP BY EXTRACT(MONTH FROM Test_date) ORDER BY month desc;").fetchdf()
# Out:
#    month  positive_cases_count  case_rank
# 0      4                  8881          1
# 1      3                  5848          2

# %% [markdown]
# **4.Find the female negative corona patients who faced cough and headache.**

# %%
conn.execute(" select count(*) as No_of_female_patients_cough_headache from df where Sex='female' and Corona='negative' and Cough_symptoms='True' and Headache='True'").fetchdf()
# Out:
#    No_of_female_patients_cough_headache
# 0                                    60

# %% [markdown]
# **5.How many elderly corona patients have faced breathing problems?**

# %%
conn.execute(" select count(*) as No_of_elderly_patients_breathing_problem from df where Age_60_above='Yes' and Shortness_of_breath='True'").fetchdf()
# Out:
#    No_of_elderly_patients_breathing_problem
# 0                                       292

# %% [markdown]
# **6.Which three symptoms were more common among COVID positive patients?**

# %%
conn.execute("SELECT Three_common_symptom, COUNT(*) AS symptom_count FROM (SELECT CASE WHEN Sore_throat = 'True' THEN 'Sore Throat' WHEN Cough_symptoms = 'True' THEN 'Cough' WHEN Fever = 'True' THEN 'Fever' WHEN Shortness_of_breath = 'True' THEN 'Shortness of Breath' WHEN Headache = 'True' THEN 'Headache' END AS Three_common_symptom FROM df WHERE Corona = 'positive') AS covid_positive_symptoms GROUP BY Three_common_symptom ORDER BY symptom_count DESC LIMIT 3; ").fetchdf()
# Out:
#   Three_common_symptom  symptom_count
# 0                Cough           5601
# 1                 None           5312
# 2                Fever           1790

# %% [markdown]
# **7.Which symptom was less common among COVID negative people?**

# %%
conn.execute("SELECT Less_common_symptom, COUNT(*) AS symptom_count FROM (SELECT CASE WHEN Sore_throat ='True' THEN 'Sore Throat' WHEN Cough_symptoms = 'True' THEN 'Cough' WHEN Fever = 'True' THEN 'Fever' WHEN Shortness_of_breath = 'True' THEN 'Shortness of Breath' WHEN Headache = 'True' THEN 'Headache' END AS Less_common_symptom FROM df WHERE corona ='negative') AS covid_negative_symptoms GROUP BY Less_common_symptom ORDER BY symptom_count ASC LIMIT 1;").fetchdf()
# Out:
#   Less_common_symptom  symptom_count
# 0            Headache             19

# %% [markdown]
# **8.What are the most common symptoms among COVID positive males whose known contact was abroad?**

# %%
conn.execute("SELECT Common_symptoms_covid_males, COUNT(*) AS symptom_count FROM ( SELECT CASE WHEN Sore_throat = 'True' THEN 'Sore Throat' WHEN Cough_symptoms = 'True' THEN 'Cough' WHEN Fever = 'True' THEN 'Fever' WHEN Shortness_of_breath = 'True' THEN 'Shortness of Breath' WHEN Headache = 'True' THEN 'Headache' END AS Common_symptoms_covid_males FROM df WHERE Corona = 'positive' AND Sex = 'male' AND Known_contact = 'Abroad') AS covid_positive_male_abroad GROUP BY Common_symptoms_covid_males ORDER BY symptom_count DESC; ").fetchdf()
# Out:
#   Common_symptoms_covid_males  symptom_count
# 0                       Cough            472
# 1                        None            170
# 2                       Fever            114
# 3                 Sore Throat             87
# 4                    Headache             23
# 5         Shortness of Breath             12

# %% [markdown]
# #**Thank You!!!**
